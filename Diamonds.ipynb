# %%
import pandas as pd
import numpy as np

# %%
location =("diamonds.csv")
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df = pd.read_csv(location,header=None)

# %%
df
# Out:
#             0      1          2      3        4      5      6      7     8   \
# 0          NaN  carat        cut  color  clarity  depth  table  price     x
# 1          1.0   0.23      Ideal      E      SI2   61.5     55    326  3.95
# 2          2.0   0.21    Premium      E      SI1   59.8     61    326  3.89
# 3          3.0   0.23       Good      E      VS1   56.9     65    327  4.05
# 4          4.0   0.29    Premium      I      VS2   62.4     58    334   4.2
# 5          5.0   0.31       Good      J      SI2   63.3     58    335  4.34
# 6          6.0   0.24  Very Good      J     VVS2   62.8     57    336  3.94
# 7          7.0   0.24  Very Good      I     VVS1   62.3     57    336  3.95
# 8          8.0   0.26  Very Good      H      SI1   61.9     55    337  4.07
# 9          9.0   0.22       Fair      E      VS2   65.1     61    337  3.87
# 10        10.0   0.23  Very Good      H      VS1   59.4     61    338     4
# ...

# %%
df = pd.read_csv(location, names=["carat","cut","color","clarity","depth","table","price","X","Y","Z",])
df.head()
# Out:
#       carat      cut  color  clarity  depth  table  price     X     Y     Z
# NaN   carat      cut  color  clarity  depth  table  price     x     y     z
#  1.0   0.23    Ideal      E      SI2   61.5     55    326  3.95  3.98  2.43
#  2.0   0.21  Premium      E      SI1   59.8     61    326  3.89  3.84  2.31
#  3.0   0.23     Good      E      VS1   56.9     65    327  4.05  4.07  2.31
#  4.0   0.29  Premium      I      VS2   62.4     58    334   4.2  4.23  2.63

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'X', 'Y',
#        'Z'],
#       dtype='object')

# %%
df= pd.read_csv(location, names = ["Unamed:0","carat", "cut", "color", "clarity", "depth", "table", "price", "X", "Y",
       "Z"])

# %%
df.head()
# Out:
#    Unamed:0  carat      cut  color  clarity  depth  table  price     X     Y  \
# 0       NaN  carat      cut  color  clarity  depth  table  price     x     y
# 1       1.0   0.23    Ideal      E      SI2   61.5     55    326  3.95  3.98
# 2       2.0   0.21  Premium      E      SI1   59.8     61    326  3.89  3.84
# 3       3.0   0.23     Good      E      VS1   56.9     65    327  4.05  4.07
# 4       4.0   0.29  Premium      I      VS2   62.4     58    334   4.2  4.23
#
#       Z
# 0     z
# 1  2.43
# 2  2.31
# 3  2.31
# 4  2.63

# %%
df
# Out:
#        Unamed:0  carat        cut  color  clarity  depth  table  price     X  \
# 0           NaN  carat        cut  color  clarity  depth  table  price     x
# 1           1.0   0.23      Ideal      E      SI2   61.5     55    326  3.95
# 2           2.0   0.21    Premium      E      SI1   59.8     61    326  3.89
# 3           3.0   0.23       Good      E      VS1   56.9     65    327  4.05
# 4           4.0   0.29    Premium      I      VS2   62.4     58    334   4.2
# 5           5.0   0.31       Good      J      SI2   63.3     58    335  4.34
# 6           6.0   0.24  Very Good      J     VVS2   62.8     57    336  3.94
# 7           7.0   0.24  Very Good      I     VVS1   62.3     57    336  3.95
# 8           8.0   0.26  Very Good      H      SI1   61.9     55    337  4.07
# 9           9.0   0.22       Fair      E      VS2   65.1     61    337  3.87
# 10         10.0   0.23  Very Good      H      VS1   59.4     61    338     4
# ...

# %%
df = pd.read_csv(location, header = None)
df
# Out:
#             0      1          2      3        4      5      6      7     8   \
# 0          NaN  carat        cut  color  clarity  depth  table  price     x
# 1          1.0   0.23      Ideal      E      SI2   61.5     55    326  3.95
# 2          2.0   0.21    Premium      E      SI1   59.8     61    326  3.89
# 3          3.0   0.23       Good      E      VS1   56.9     65    327  4.05
# 4          4.0   0.29    Premium      I      VS2   62.4     58    334   4.2
# 5          5.0   0.31       Good      J      SI2   63.3     58    335  4.34
# 6          6.0   0.24  Very Good      J     VVS2   62.8     57    336  3.94
# 7          7.0   0.24  Very Good      I     VVS1   62.3     57    336  3.95
# 8          8.0   0.26  Very Good      H      SI1   61.9     55    337  4.07
# 9          9.0   0.22       Fair      E      VS2   65.1     61    337  3.87
# 10        10.0   0.23  Very Good      H      VS1   59.4     61    338     4
# ...

# %%
df = pd.read_csv(location)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
Fname = ["Natnnial","Rediet","Dagi","Euni"]
Lname = ["Haile","Alemayehu","Mesfin","Firdu"]
Age = [27,60,30,31]
Gender = ["Male","Male","Female","Male"]
Person = list(zip(Fname,Lname,Age,Gender))

# %%
Person
# Out:
# [('Natnnial', 'Haile', 27, 'Male'),
#  ('Rediet', 'Alemayehu', 60, 'Male'),
#  ('Dagi', 'Mesfin', 30, 'Female'),
#  ('Euni', 'Firdu', 31, 'Male')]

# %%
df = pd.DataFrame(data = Person, columns = ["Fname","Lname","Age","Gender"])
df.to_csv("person.csv",  index = False)

# %%
df.count()
# Out:
# Fname     4
# Lname     4
# Age       4
# Gender    4
# dtype: int64

# %%
df.dtypes
# Out:
# Fname    object
# Lname    object
# Age       int64
# dtype: object

# %%
df.groupby('Gender').count()
# Out:
#         Fname  Lname  Age
# Gender
# Female      1      1    1
# Male        3      3    3

# %%
df
# Out:
#       Fname      Lname  Age  Gender
# 0  Natnnial      Haile   27    Male
# 1    Rediet  Alemayehu   60    Male
# 2      Dagi     Mesfin   30  Female
# 3      Euni      Firdu   31    Male

# %%
df.groupby('Gender').count()
# Out:
#         Fname  Lname  Age
# Gender
# Female      1      1    1
# Male        3      3    3

# %%
df["Fname"].groupby(df['Gender']).count()
# Out:
# Gender
# Female    1
# Male      3
# Name: Fname, dtype: int64

# %%
pd.pivot_table(df, values =['Fname'],index=['Gender'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-95-6be6987dacca> in <module>()
# ----> 1 pd.pivot_table(df, values =['Fname'],index=['Gender']).count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     134
#     135     grouped = data.groupby(keys)
# --> 136     agged = grouped.agg(aggfunc)
#     137
#     138     table = agged
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4034         versionadded=''))
#    4035     def aggregate(self, arg, *args, **kwargs):
# -> 4036         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4037
#    4038     agg = aggregate
#
# ...

# %%
df
# Out:
#       Fname      Lname  Age  Gender
# 0  Natnnial      Haile   27    Male
# 1    Rediet  Alemayehu   60    Male
# 2      Dagi     Mesfin   30  Female
# 3      Euni      Firdu   31    Male

# %%
location
# Out:
# 'diamonds.csv'

# %%
location.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-20c1d502f504> in <module>()
# ----> 1 location.isnull().sum()
#
# AttributeError: 'str' object has no attribute 'isnull'

# %%
df= pd.read_csv(location)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
dup=df.duplicated()

# %%
df.loc[dup]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
df.groupby("color").count()
# Out:
#        Unnamed: 0  carat    cut  clarity  depth  table  price      x      y  \
# color
# D            6775   6775   6775     6775   6775   6775   6775   6775   6775
# E            9797   9797   9797     9797   9797   9797   9797   9797   9797
# F            9542   9542   9542     9542   9542   9542   9542   9542   9542
# G           11292  11292  11292    11292  11292  11292  11292  11292  11292
# H            8304   8304   8304     8304   8304   8304   8304   8304   8304
# I            5422   5422   5422     5422   5422   5422   5422   5422   5422
# J            2808   2808   2808     2808   2808   2808   2808   2808   2808
#
#            z
# color
# D       6775
# E       9797
# F       9542
# G      11292
# H       8304
# I       5422
# J       2808

# %%
df.sort_values('carat')
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 31593       31594   0.20    Premium     E     VS2   61.1   59.0    367   3.81
# 31597       31598   0.20      Ideal     D     VS2   61.5   57.0    367   3.81
# 31596       31597   0.20    Premium     F     VS2   62.6   59.0    367   3.73
# 31595       31596   0.20      Ideal     E     VS2   59.7   55.0    367   3.86
# 31594       31595   0.20    Premium     E     VS2   59.7   62.0    367   3.84
# 31600       31601   0.20    Premium     D     VS2   62.3   60.0    367   3.73
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367   3.79
# 31601       31602   0.20    Premium     D     VS2   61.7   60.0    367   3.77
# 31598       31599   0.20  Very Good     E     VS2   63.4   59.0    367   3.74
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345   3.79
# ...
